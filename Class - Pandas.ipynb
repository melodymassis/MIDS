# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/melodymassis/Documents/MIDS/yelp_business - yelp_business.csv')

# %%
df.head()
# Out:
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  33.330690 -111.978599    4.0            22        1
# ...

# %%
df.describe()
# Out:
#             latitude      longitude          stars   review_count  \
# count  174566.000000  174566.000000  174567.000000  174567.000000
# mean       38.627312     -92.679009       3.632196      30.137059
# std         5.389012      26.240079       1.003739      98.208174
# min       -36.086009    -142.466650       1.000000       3.000000
# 25%        33.631550    -112.125879       3.000000       4.000000
# 50%        36.144257     -89.410128       3.500000       8.000000
# 75%        43.606181     -79.657609       4.500000      23.000000
# max        89.999314     115.086769       5.000000    7361.000000
#
#              is_open
# count  174567.000000
# mean        0.840376
# std         0.366258
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
df.loc[:]
# Out:
#                    business_id                           name neighborhood  \
# 0       FYWN1wneV18bWNgQjJ2GNg             "Dental by Design"          NaN
# 1       He-G7vWjzVUysIKrfNbPUQ          "Stephen Szabo Salon"          NaN
# 2       KQPW8lFf1y5BT2MxiSZ3QA        "Western Motor Vehicle"          NaN
# 3       8DShNS-LuFqpEWIp0HxijA             "Sports Authority"          NaN
# 4       PfOCPjBrlQAnz__NXj9h_w     "Brick House Tavern + Tap"          NaN
# ...                        ...                            ...          ...
# 174562  ALV5R8NkZ1KGOZeuZl3u0A                "Whitby Toyota"          NaN
# 174563  gRGalHVu6BcaUDIAGVW_xQ            "Village Auto Body"          NaN
# 174564  XXvZBIHoJBU5d6-a-oyMWQ                          "AAM"          NaN
# 174565  lNpPGgM96nPIYM1shxciHg  "Bronze Beauty Spray Tanning"          NaN
# 174566  viKaP26BcHU6cLx8sf4gKg             "Phoenix Pharmacy"          NaN
#
# ...

# %%
df.value_counts('state')
# Out:
# state
# AZ     52214
# NV     33086
# ON     30208
# NC     12956
# OH     12609
#        ...
# 3          1
# KY         1
# MN         1
# MT         1
# ZET        1
# Length: 67, dtype: int64

# %%
df.drop_duplicates()
# Out:
#                    business_id                           name neighborhood  \
# 0       FYWN1wneV18bWNgQjJ2GNg             "Dental by Design"          NaN
# 1       He-G7vWjzVUysIKrfNbPUQ          "Stephen Szabo Salon"          NaN
# 2       KQPW8lFf1y5BT2MxiSZ3QA        "Western Motor Vehicle"          NaN
# 3       8DShNS-LuFqpEWIp0HxijA             "Sports Authority"          NaN
# 4       PfOCPjBrlQAnz__NXj9h_w     "Brick House Tavern + Tap"          NaN
# ...                        ...                            ...          ...
# 174562  ALV5R8NkZ1KGOZeuZl3u0A                "Whitby Toyota"          NaN
# 174563  gRGalHVu6BcaUDIAGVW_xQ            "Village Auto Body"          NaN
# 174564  XXvZBIHoJBU5d6-a-oyMWQ                          "AAM"          NaN
# 174565  lNpPGgM96nPIYM1shxciHg  "Bronze Beauty Spray Tanning"          NaN
# 174566  viKaP26BcHU6cLx8sf4gKg             "Phoenix Pharmacy"          NaN
#
# ...

# %%
state = df.groupby('city').count()
print(state)
# Out:
#                 business_id  name  neighborhood  address  state  postal_code  \
# city
# 110 Las Vegas             1     1             1        1      1            1
# AGINCOURT                 1     1             1        1      1            1
# Aberdour                  1     1             0        1      1            1
# Aberlady                  2     2             0        2      2            2
# Ahwahtukee                1     1             0        1      1            1
# ...                     ...   ...           ...      ...    ...          ...
# oakville                  1     1             0        1      1            1
# peoria                    1     1             0        1      1            1
# toronto                   5     5             3        5      5            5
# Île des Soeurs            1     1             1        1      1            1
# Île-des-Soeurs            1     1             1        1      1            1
#
# ...

# %%
counts = df.sort_values('state')
print(counts)
# Out:
#                    business_id               name neighborhood  \
# 17311   -HpY7t06AtvasLfJJmY2ww          "Husmann"          NaN
# 99375   VR6vnB56lpH1Oa8rYIXpUw           "Go'Bua"          NaN
# 54867   WU_41ySU7HoF62lpTr633w       "Moss Sushi"          NaN
# 66663   39NX6v8cWKDnXIcVPFiFGQ          "Divinum"          NaN
# 141499  7MrVKrTj_cULIAF8Z3_P-A  "Ming Restaurant"          NaN
# ...                        ...                ...          ...
# 155168  5ho3ULJKSikoRJr-xpM4SQ          "Bramble"        Leith
# 93013   mmqSJyO2FNIlV18g4dMiWw    "The Hawes Inn"          NaN
# 28827   PtOViDy0tqoocic2DAgd6A        "Debenhams"     New Town
# 156754  nWz3HA2RvJDZzDNeonsA_w          "Nando's"     New Town
# 52815   SLqpLeF3gq6nnx6_JoE7-A       "5150 Wraps"          NaN
#
#                                       address               city state  \
# 17311                          "Værftsgata 2"               Moss     1
# ...

# %%
fillna_drill = df.fillna
